# %%
import os

# %%
for pasta in os.listdir(".."):
    if os.path.isdir(os.path.join("..", pasta)):
        #print(pasta)
        for subpasta in os.listdir(os.path.join("..", pasta)):
            print(subpasta)
            # if os.path.isdir(subpasta):
            #     print(os.listdir(subpasta))
# Out:
# chat_agent.py
# __init__.py
# __pycache__
# ollama
# pdfs
# vectorstore
# __init__.py
# model_loader.py
# __init__.py
# __pycache__
# notebook.ipynb
# config.py
# ingest.py
# paths.py
# prompts.py
# retriever.py
# __init__.py
# __pycache__
# pdf_extractor.py
# pdf_finder.py
# __init__.py
# __pycache__
